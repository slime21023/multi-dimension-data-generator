# %%
from utils.make_file import *

normal_npz(mu=10, sigma=0.1, size=(1000,2))
uniform_npz(low=10, high=300, size=(1000,2))
beta_npz(a=5, b=5, size=(1000,2))
exponential_npz(scale=3, size=(1000, 2))
lognormal_npz(mean=50, sigma=1, size=(1000, 2))
chisquare_npz(df=10, size=(1000,2))

# %%
import numpy as np
import seaborn as sns
import pandas as pd


data = np.load("data/2-dims-uniform-1000.npz")
keys = data['keys'].reshape(1000, 2)
df = pd.DataFrame(keys, columns=["x", "y"])

sns.scatterplot(df["x"], df["y"]).plot()
# Out:
# d:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# []
